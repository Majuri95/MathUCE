# %% [markdown]
# <a href="https://colab.research.google.com/github/Majuri95/MathUCE/blob/main/Apuntes_de_la_Clase_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #🧮 Funciones: Utilidad, Tipos y Composición
# ## 📘Introducción:
#
# Las funciones son herramientas matemáticas fundamentales que permiten modelar relaciones entre variables y son esenciales en diversos campos del conocimiento. En este análisis detallado, exploraremos la utilidad, tipos y composición de las funciones, proporcionando una comprensión profunda de estos conceptos.
# ##🔍Utilidad de las funciones:
#
# Las funciones ofrecen una amplia gama de beneficios en la resolución de problemas y el análisis de datos:
#
# * Modelado de relaciones: Permiten representar la relación entre dos conjuntos de números, facilitando la comprensión de fenómenos y comportamientos.
#
# * Simplificación de cálculos: Facilitan la resolución de problemas complejos al encapsular operaciones repetitivas en una única expresión.
#
# * Generalización de soluciones: Permiten encontrar soluciones generales a problemas similares, sin necesidad de repetir cálculos para cada caso específico.
#
# * Análisis de cambio: Facilitan el estudio de cómo cambia el valor de salida a medida que varía el valor de entrada, proporcionando información sobre la sensibilidad de la función.
#
# * Comunicación matemática: Brindan una forma concisa y precisa de expresar relaciones entre variables, mejorando la comunicación y el intercambio de ideas.
#
# ## 👨‍💻 Definición y Representación de Funciones
#
# Una función es una regla de asociación que asigna a cada elemento de un conjunto de partida (A) un elemento único en un conjunto de llegada (B). La notación matemática estándar para una función es $(f: A \rightarrow B$). Visualmente, podemos imaginar esto como un mapa que toma cada elemento $(x$) en $(A$fv) y lo asocia con un elemento $(f(x)$) en $(B$).
#
#
# Imaginemos que $(A$) es un conjunto de números y $(B$) es un conjunto de colores. La función $(f$) podría representar una regla que asocia cada número con un color específico.
#
# ![Texto alternativo](https://upload.wikimedia.org/wikipedia/commons/5/5c/L%C3%ADmite_de_una_funci%C3%B3n_f.gif)
#
# ##🧩Tipos de funciones:
#
# Existe una amplia variedad de funciones, cada una con características y aplicaciones específicas:
#
# * Función lineal: Representada por y = mx + b, donde m y b son constantes. Su gráfica es una línea recta.
# ![Texto alternativo](https://upload.wikimedia.org/wikipedia/commons/4/4c/Funci%C3%B3n_lineal.svg)
#
# * Función cuadrática: Representada por y = ax^2 + bx + c, donde a, b y c son constantes. Su gráfica es una parábola.
#
# ![Texto alternativo](https://upload.wikimedia.org/wikipedia/commons/f/f8/Polynomialdeg2.svg)
#
# * Función exponencial: Representada por y = a^x, donde a es una constante positiva (a ≠ 1). Su gráfica muestra un crecimiento o decrecimiento exponencial.
#
# ![Texto alternativo](https://www.fisicalab.com/sites/all/files/contenidos/matematicas/9097_f_exponenciales/graficas_exponenciales.jpg)
#
# * Función logarítmica: Representada por y = log_a(x), donde a es una constante positiva (a ≠ 1). Su gráfica es la inversa de la función exponencial.
#
# ![Texto alternativo](https://www.fisicalab.com/sites/all/files/contenidos/matematicas/9209_f_logaritmicas/otras_graficas_logaritmicas.jpg)
#
# * Función trigonométrica: Representada por y = sin(x), y = cos(x), y = tan(x). Sus gráficas muestran comportamientos periódicos.
#
# ![Texto alternativo](https://www.varsitytutors.com/assets/vt-hotmath-legacy/hotmath_help/topics/trigonometic-functions/sine.gif)
#
# * Función compuesta: Se obtiene al combinar dos o más funciones, aplicando una función al resultado de otra.
#
# ![Texto alternativo](https://www.neurochispas.com/wp-content/uploads/2022/08/diagrama-de-mapeo-de-una-funcion-compuesta-g-of-f-600x281.png)
#
# * Función inversa: Representa la función que "deshace" lo que hace la función original. Si f(x) = y, entonces f^(-1)(y) = x.
#
# ![Texto alternativo](https://www.fisicalab.com/sites/all/files/contenidos/matematicas/2225_f_inversa/ejemplos_inversas.jpg)
#
# ### Ejemplos

# %%
import math
import matplotlib.pyplot as plt

# Función lineal
def funcion_lineal(x, m, b):
  """
  Función lineal y = mx + b.

  Args:
    x: Valor de entrada (variable independiente).
    m: Pendiente de la recta.
    b: Intercepto en el eje y.

  Returns:
    Valor de salida (imagen) de la función lineal para el valor de entrada x.
  """
  return m * x + b

# Función cuadrática
def funcion_cuadratica(x, a, b, c):
  """
  Función cuadrática y = ax^2 + bx + c.

  Args:
    x: Valor de entrada (variable independiente).
    a: Coeficiente cuadrático.
    b: Coeficiente lineal.
    c: Término independiente.

  Returns:
    Valor de salida (imagen) de la función cuadrática para el valor de entrada x.
  """
  return a * x**2 + b * x + c

# Función exponencial
def funcion_exponencial(x, a):
  """
  Función exponencial y = a^x.

  Args:
    x: Valor de entrada (variable independiente).
    a: Base de la exponencial (a > 0, a ≠ 1).

  Returns:
    Valor de salida (imagen) de la función exponencial para el valor de entrada x.
  """
  return a**x

# Función logarítmica
def funcion_logaritmica(x, a):
  """
  Función logarítmica y = log_a(x).

  Args:
    x: Valor de entrada (variable independiente) (x > 0).
    a: Base de la logaritmo (a > 0, a ≠ 1).

  Returns:
    Valor de salida (imagen) de la función logarítmica para el valor de entrada x.
  """
  return math.log(x, a)

# Función trigonométrica seno
def funcion_trigonometrica_sin(x):
  """
  Función trigonométrica seno y = sin(x).

  Args:
    x: Valor de entrada (variable independiente) en radianes.

  Returns:
    Valor de salida (imagen) de la función seno para el valor de entrada x.
  """
  return math.sin(x)

# Función trigonométrica coseno
def funcion_trigonometrica_cos(x):
  """
  Función trigonométrica coseno y = cos(x).

  Args:
    x: Valor de entrada (variable independiente) en radianes.

  Returns:
    Valor de salida (imagen) de la función coseno para el valor de entrada x.
  """
  return math.cos(x)

# Función trigonométrica tangente
def funcion_trigonometrica_tan(x):
  """
  Función trigonométrica tangente y = tan(x).

  Args:
    x: Valor de entrada (variable independiente) en radianes.

  Returns:
    Valor de salida (imagen) de la función tangente para el valor de entrada x.
  """
  return math.tan(x)

# Función inversa lineal
def funcion_inversa_lineal(y, m, b):
  """
  Función inversa de la función lineal y = mx + b.

  Args:
    y: Valor de salida (imagen).
    m: Pendiente de la recta.
    b: Intercepto en el eje y.

  Returns:
    Valor de entrada (preimagen) x que satisface y = mx + b.
  """
  return (y - b) / m

# %% [markdown]
# ## 🧩Función Sobreyectiva, Biyectiva, Inyectiva, Inversa y Compuesta
#
# #### 🌈Función Sobreyectiva (Suprayectiva o Exhaustiva):
#
# Una función f: X → Y se considera sobreyectiva si para cada elemento y perteneciente al codominio Y, existe al menos un elemento x del dominio X tal que f(x) = y. En otras palabras, la imagen de la función (el conjunto de valores que toma f(x) para todos los x en el dominio) cubre todo el codominio.
#
# ####Representación gráfica:
#
# En una gráfica de una función sobreyectiva, cada punto del codominio Y se encuentra alineado con al menos un punto del dominio X.
#
#
# #### Ejemplos de funciones sobreyectivas:
#
# La función f(x) = x^2 + 1, donde X es el conjunto de todos los números reales y Y es el conjunto de números mayores o iguales a 1.
# La función g(x) = 2x + 1, donde X es el conjunto de todos los números reales y Y es el conjunto de todos los números reales.
# Función Biyectiva (Inyectiva y Sobreyectiva a la vez):
#
# Una función f: X → Y se considera biyectiva si cumple dos condiciones:
#
# ### 🔄Función Biyectividad:
#
# Para cualquier par de elementos distintos x1 y x2 en el dominio X, sus imágenes f(x1) y f(x2) también son distintas en el codominio Y. En otras palabras, la función no asigna el mismo valor de salida a dos elementos de entrada diferentes.
#
# Sobreyectividad: La función f es sobreyectiva, es decir, cubre todo el codominio Y.
#
# ####Representación gráfica:
#
# En una gráfica de una función biyectiva, cada punto del codominio Y se encuentra alineado con exactamente un punto del dominio X, y viceversa. La gráfica de una función biyectiva es una recta diagonal.
#
# ####Ejemplos de funciones biyectivas:
#
# La función f(x) = x, donde X e Y son el conjunto de todos los números reales.
# La función g(x) = 2x - 1, donde X es el conjunto de todos los números reales y Y es el conjunto de todos los números reales excepto 1/2.
#
# ###📊Función Inyectiva (Univalente):
#
# Una función f: X → Y se considera inyectiva si para cualquier par de elementos distintos x1 y x2 en el dominio X, sus imágenes f(x1) y f(x2) también son distintas en el codominio Y. En otras palabras, la función no asigna el mismo valor de salida a dos elementos de entrada diferentes.
#
# ####Representación gráfica:
#
# En una gráfica de una función inyectiva, cada punto del codominio Y se encuentra alineado con a lo sumo un punto del dominio X.
#
# ####Ejemplos de funciones inyectivas:
#
# La función f(x) = x^2, donde X es el conjunto de todos los números reales y Y es el conjunto de todos los números mayores o iguales a 0.
# La función g(x) = e^x, donde X es el conjunto de todos los números reales y Y es el conjunto de todos los números reales positivos.
# Función Inversa:
#
# Para una función f: X → Y que sea biyectiva, existe una función inversa f^(-1): Y → X tal que para cualquier elemento x en el dominio X y su imagen y en el codominio Y, se cumple que f^(-1)(y) = x y f(f^(-1)(y)) = y. En otras palabras, la función inversa "deshace" lo que hace la función original.
#
# ### 📊 Propiedades de la función inversa:
#
# La función inversa de una función biyectiva es también biyectiva.
# La gráfica de la función inversa es la simétrica de la gráfica de la función original respecto a la bisectriz de los cuadrantes.
# Ejemplo de función inversa:
#
# La función f(x) = x^2, donde X es el conjunto de todos los números reales no negativos y Y es el conjunto de todos los números reales no negativos, tiene una función inversa f^(-1
#
# ![Texto alternativo](https://www.disfrutalasmatematicas.com/conjuntos/images/function-mapping.svg)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definición de funciones
def f_inyectiva(x):
    return x

def f_sobreyectiva(x):
    return np.tanh(x)

def f_biyectiva(x):
    return x**2

def f_inversa(x):
    return np.sqrt(x)

# Valores de x para graficar
x = np.linspace(-1, 1, 200)

# Crear la figura
plt.figure(figsize=(6, 4))

# Función Inyectiva
plt.subplot(131)
plt.plot(x, f_inyectiva(x), label='$f(x) = x$', color='blue')
plt.title('Función Inyectiva')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()

# Función Sobreyectiva
plt.subplot(132)
plt.plot(x, f_sobreyectiva(x), label='$f(x) = tanh(x)$', color='orange')
plt.title('Función Sobreyectiva')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()

# Función Biyectiva
plt.subplot(133)
plt.plot(x, f_biyectiva(x), label='$f(x) = x^3$', color='green')
plt.title('Función Biyectiva')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()

# Función Inversa

plt.plot(x, f_inversa(x), label='$f^{-1}(x) = \sqrt{x}$', color='red')
plt.title('Función Inversa')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()

# Ajustar el diseño de la figura
plt.tight_layout()

# Mostrar la figura
plt.show()
# Out:
# <ipython-input-13-59448f1e0c50>:15: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(x)

# %% [markdown]
# ###🚰 Función de Utilidad
#
# Consideremos un ejemplo simple en el que el único bien disponible es agua. La función de utilidad, en este caso, puede representarse como $( u(x) $), donde $( x $) es la cantidad de agua consumida y \( u(x) \) es la utilidad obtenida.
#
# La utilidad marginalmente decrece, lo que significa que cada unidad adicional de agua proporciona una utilidad menor que la anterior.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Definimos una función de utilidad diferente
def u(x, y):
    return np.sin(x) * np.cos(y)

# Rango de valores para x e y
x = np.linspace(-2, 2, 200)
y = np.linspace(-2, 2, 200)
X, Y = np.meshgrid(x, y)
Z = u(X, Y)

# Creamos la figura
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot(111, projection='3d')

# Gráfico de la superficie de la función de utilidad
surf = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none')

# Contornos en el plano
contours = ax.contour(X, Y, Z, levels=np.linspace(-1, 1, 10), cmap='autumn', linestyles="solid")

# Etiquetas y título
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Utilidad U(x, y)')
ax.set_title('Superficie de la Función de Utilidad y Contornos')

# Barra de color
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### ⛺ Notación Matemática de la Función de Utilidad
#
# 1. **Definición de la Función de Utilidad**:
#    $[
#    U: \mathbb{R}^2_+ \rightarrow \mathbb{R}^+
#    ]$
#    Esta notación indica que la función de utilidad \( U \) toma como entrada un par de números reales no negativos $(( \mathbb{R}^2_+ ))$ y produce un número real no negativo $(( \mathbb{R}^+ ))$.
#
# 2. **Expresión de la Función de Utilidad**:
#    $[
#    (x, y) \rightarrow u(x, y)
#    ]$
#    Aquí, $( (x, y) )$ son las cantidades de dos bienes, y $( u(x, y) )$ es el nivel de utilidad asociado con esas cantidades.
#
# 3. **Conjuntos de Nivel**:
#    $[
#    \{ (x, y) \in \mathbb{R}^2_+ : u(x, y) = 10 \}
#    ]$
#    Esto representa el conjunto de todos los pares $((x, y))$ en $(\mathbb{R}^2_+)$ que producen una utilidad de 10. En el gráfico, estos conjuntos de nivel están representados por curvas de nivel $(isocuantas)$ en rojo
