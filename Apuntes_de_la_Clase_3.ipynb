# %% [markdown]
# <a href="https://colab.research.google.com/github/Majuri95/MathUCE/blob/main/Apuntes_de_la_Clase_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧩 Clase 3: Introducción a Python. Sistemas Numéricos y Cardinalidad
#
# # 📖 Introducción a Python
# Python es un lenguaje de programación de alto nivel, conocido por su simplicidad y versatilidad, que es ampliamente utilizado en diversas disciplinas como la ciencia de datos, desarrollo web, automatización, y más. En esta sección, exploraremos cómo Python maneja diferentes sistemas numéricos y el concepto de cardinalidad.
# ##🌍 Historia de Python
# Python fue desarrollado por Guido van Rossum en 1991. Desde entonces, ha evolucionado y se ha convertido en uno de los lenguajes de programación más populares y versátiles del mundo.
#
# ![Texto alternativo](https://i.blogs.es/1d8a5b/python1/1366_2000.jpg)
#
#
# ## 📅 Principios de diseño
#
# 1. Lo bello es mejor que lo feo.
# 2. Lo explícito es mejor que lo implícito.
# 3. Lo simple es mejor que lo complejo.
# 4. Lo complejo es mejor que lo complicado.
# 5. La legibilidad cuenta.
#
# Estos principios, junto con otros, se pueden encontrar en el módulo `this` en Python. 📜
#
# ## 🧘‍♂️ ¿Por qué aprender Python?
#
# 1. **Simplicidad y legibilidad**: La sintaxis de Python es clara y fácil de leer.
# 2. **Versatilidad**: Python se utiliza en muchas disciplinas, como desarrollo web, ciencia de datos, automatización, inteligencia artificial y más.
# 3. **Comunidad activa**: Python tiene una gran comunidad de desarrolladores que contribuyen con bibliotecas y herramientas.
# 4. **Bibliotecas y frameworks**: Existen muchas bibliotecas y frameworks disponibles que facilitan el desarrollo de proyectos.
# #✅Ventajas de Python
#   * Sintaxis clara y amigable: La simplicidad de la sintaxis de Python facilita la comprensión y la creación de código, lo que agiliza el desarrollo y la colaboración entre equipos.
#   * Amplia comunidad y soporte: Python cuenta con una comunidad activa de desarrolladores que contribuyen con bibliotecas, tutoriales y soluciones a problemas en foros. Esto ofrece un valioso apoyo para el aprendizaje y la resolución de problemas.
#   * Biblioteca estándar completa: Python incluye una biblioteca estándar extensa que abarca diversas áreas, desde la manipulación de archivos hasta el desarrollo web. Esto permite a los desarrolladores aprovechar herramientas existentes sin necesidad de reinventar la rueda.
#   * Versatilidad y portabilidad: Python es un lenguaje multiplataforma, lo que significa que el código escrito en Python puede ejecutarse en diferentes sistemas operativos sin modificaciones significativas. Esto facilita el desarrollo de aplicaciones que pueden ser utilizadas en una variedad de entornos.
#   * Desarrollo rápido de prototipos: La facilidad de escritura y la sintaxis concisa de Python lo convierten en una herramienta ideal para el desarrollo rápido de prototipos. Esto permite a los desarrolladores probar y experimentar con ideas de forma rápida antes de comprometerse con implementaciones más extensas.
#   * Integración fluida con otros lenguajes:Python puede integrarse fácilmente con otros lenguajes, como C y C++. Esto permite a los desarrolladores aprovechar código existente y obtener un rendimiento óptimo cuando sea necesario.
# # ❌ Desventajas de Python
#  * Rendimiento: Python, al ser un lenguaje interpretado, puede ser más lento en comparación con lenguajes compilados como C++ o Java. Esto puede ser un inconveniente para aplicaciones que requieren un alto rendimiento o un procesamiento intensivo.
#  * Uso de memoria: La flexibilidad de los tipos de datos en Python puede ocasionar un mayor consumo de memoria en comparación con otros lenguajes. Esto puede ser un problema en equipos con recursos limitados.
#  * Desarrollo móvil: Si bien Python es útil para el desarrollo web y de escritorio, existen lenguajes más especializados y eficientes para la creación de aplicaciones móviles.
#  * Seguridad: Al ser un lenguaje interpretado, Python puede ser más susceptible a ciertos tipos de ataques e intrusiones de seguridad en comparación con lenguajes compilados.
#  * Dependencia de bibliotecas: Python depende en gran medida de bibliotecas externas para realizar tareas específicas. Esto puede aumentar la complejidad del proyecto y generar problemas de compatibilidad en algunos casos.
#  * Curva de aprendizaje para principiantes: A pesar de su simplicidad general, la sintaxis de Python puede resultar un poco diferente a la de otros lenguajes, lo que puede presentar una curva de aprendizaje inicial para principiantes
#
# # 🌟 Sistemas Numéricos
#
# Los sistemas numéricos son métodos para representar números. Python soporta varios sistemas numéricos, los más comunes son el decimal, binario, octal y hexadecimal.

# %% [markdown]
# 1. Decimal (Base 10): Es el sistema numérico más utilizado, que usa los dígitos del 0 al 9. Por ejemplo, 123 en decimal es simplemente 123.

# %% [markdown]
# 2. Binario (Base 2): Utiliza solo los dígitos 0 y 1. Es el sistema numérico fundamental en la informática y la electrónica digital. En Python, los números binarios se representan con el prefijo 0b o 0B. Por ejemplo:

# %%
binario = 0b1010  # Representa el número 10 en decimal

# %% [markdown]
# 3. Octal (Base 8): Utiliza los dígitos del 0 al 7. En Python, los números octales se representan con el prefijo 0o o 0O. Por ejemplo:

# %%
octal = 0o12  # Representa el número 10 en decimal

# %% [markdown]
#  4. Hexadecimal (Base 16): Utiliza los dígitos del 0 al 9 y las letras A a F (o a-f) para representar valores del 10 al 15. En Python, los números hexadecimales se representan con el prefijo 0x o 0X. Por ejemplo:

# %%
hexadecimal = 0xA  # Representa el número 10 en decimal

# %% [markdown]
# Python proporciona funciones integradas para convertir entre estos sistemas numéricos:
#
# bin() para convertir a binario.
#
# oct() para convertir a octal.
#
# hex() para convertir a hexadecimal.
#
# Ejemplo:

# %%
numero = 10
print(bin(numero))  # Output: 0b1010
print(oct(numero))  # Output: 0o12
print(hex(numero))  # Output: 0xA
# Out:
# 0b1010
# 0o12
# 0xa

# %% [markdown]
# #📊Cardinalidad
# ##📏 Qué es Cardinalidad?
#
# En el ámbito de las matemáticas, la cardinalidad, también conocida como número cardinal, se refiere a la medida de la "cantidad de elementos" que conforman un conjunto.
#
# En palabras más simples, la cardinalidad nos indica cuántos elementos tiene un conjunto. Se representa comúnmente con el símbolo "|A|", donde A es el nombre del conjunto en cuestión.
#
# Para conjuntos finitos, como por ejemplo A = {2, 4, 6}, la cardinalidad se calcula simplemente contando el número de elementos. En este caso, el conjunto A tiene 3 elementos, por lo que su cardinalidad sería |A| = 3.
#
# Sin embargo, la cardinalidad también se aplica a conjuntos infinitos, donde contar los elementos de forma individual no es posible. En estos casos, se utilizan conceptos más avanzados como los números cardinales infinitos.
#
# ![cardinalidad_manzana.png](data:image/png;base64,...)
#
# ##🔢Ejemplo de cardinalidad en conjuntos infinitos:
#
# El conjunto de los números naturales (N): N = {1, 2, 3, ...}, tiene una cardinalidad infinita denominada aleph-null (ℵ₀).
#
# El conjunto de los números enteros (Z): Z = {..., -2, -1, 0, 1, 2, ...}, también tiene cardinalidad aleph-null (ℵ₀), ya que contiene a los números naturales como subconjunto.
#
# En el contexto de las bases de datos:
#
# La cardinalidad se utiliza para describir la relación entre dos entidades en un modelo de datos. Indica cuántas veces una instancia de una entidad puede estar relacionada con instancias de otra entidad.
#
# ##📚Tipos de cardinalidad en bases de datos:
#
# Uno a uno (1:1): Una instancia de una entidad puede estar relacionada con máximo una instancia de otra entidad.
#
# Uno a varios (1:N): Una instancia de una entidad puede estar relacionada con varias instancias de otra entidad.
#
# Varios a varios (N:N): Una instancia de una entidad puede estar relacionada con varias instancias de otra entidad, y viceversa.
#
# ### 📊 Cardinalidad de Conjuntos
#
# La **cardinalidad** de un conjunto es una medida del "número de elementos" en el conjunto. Los conjuntos pueden ser finitos o infinitos. La cardinalidad se representa comúnmente como |A|, donde A es el conjunto.
#
# Ejemplos:
# 1. Números Aleatorios
# - Si A = {1, 2, 3}, entonces |A| = 3.
# - Si B = {x ∈ ℕ | x < 10}, entonces |B| = 9.

# %%
# Ejemplo de cardinalidad
A = {1, 2, 3}
B = set(range(10))

print(f"Cardinalidad de A: {len(A)}")
print(f"Cardinalidad de B: {len(B)}")
# Out:
# Cardinalidad de A: 3
# Cardinalidad de B: 10

# %% [markdown]
# 2. Conjunto de números pares:

# %%
# Definir el conjunto de números pares
pares = {2, 4, 6, 8, 10}

# Calcular la cardinalidad (número de elementos) del conjunto
cardinalidad_pares = len(pares)

# Imprimir la cardinalidad
print("Cardinalidad del conjunto de números pares:", cardinalidad_pares)
# Out:
# Cardinalidad del conjunto de números pares: 5

# %% [markdown]
# 3. Unión de dos conjuntos:

# %%
# Definir dos conjuntos
conjunto_A = {1, 2, 3}
conjunto_B = {3, 4, 5}

# Calcular la unión de los conjuntos (A U B)
union_AB = conjunto_A | conjunto_B

# Calcular la cardinalidad de la unión
cardinalidad_union = len(union_AB)

# Imprimir la cardinalidad
print("Cardinalidad de la unión (A U B):", cardinalidad_union)
# Out:
# Cardinalidad de la unión (A U B): 5

# %%
# Generación de un Diagrama de Venn para dos conjuntos
from matplotlib_venn import venn2
import matplotlib.pyplot as plt # Import the matplotlib.pyplot module

# Conjuntos de Ejemplo
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7, 8}

# Diagrama de Venn
plt.figure(figsize=(8, 8))
venn2([A, B], ('Conjunto A', 'Conjunto B'))
plt.title("Diagrama de Venn de los Conjuntos A y B")
plt.show()
