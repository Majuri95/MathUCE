# %% [markdown]
# <a href="https://colab.research.google.com/github/Majuri95/MathUCE/blob/main/Apuntes_de_la_Clase_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🤖 Clase 2: Algoritmos de Programación y Sistemas Numéricos
#
# #🧩 Introducción:
#
# Los algoritmos de programación y los sistemas numéricos son dos pilares fundamentales de la informática. Los algoritmos proporcionan las instrucciones paso a paso para resolver problemas de manera eficiente, mientras que los sistemas numéricos permiten representar y manipular información numérica en computadoras. En este análisis detallado, exploraremos ambos conceptos en profundidad, abarcando sus fundamentos, clasificación, aplicaciones y relaciones.
#
# ##👨‍💻Algoritmos de Programación:
#
# Un algoritmo es una secuencia finita y ordenada de pasos lógicos y bien definidos que se diseñan para resolver un problema específico o realizar una tarea. Se caracterizan por su precisión, completitud, generalidad y finitud.
#
# **Algoritmo en lenguaje común**: Conjunto de datos, pasos o procesos para llegar a un resultado (como hacer fideos, en lenguaje común).
#
# **Algoritmo en lenguaje computacional**: Lenguaje que depende de si es interpretativo o de máquina, que una computadora usa para resolver un problema.
#
# ###🔄Clasificación de algoritmos:
#
# Los algoritmos se pueden clasificar según diversos criterios:
#
# **Función:**
# * Algoritmos de búsqueda: Localizan un elemento específico dentro de un conjunto de datos.
# * Algoritmos de ordenación: Ordenan un conjunto de elementos según un criterio específico.
# * Algoritmos de recorrido: Atraviesan y procesan todos los elementos de una estructura de datos.
# * Algoritmos de cálculo: Realizan operaciones matemáticas sobre datos.
#
# **Complejidad:**
# * Algoritmos de tiempo constante: El tiempo de ejecución no depende del tamaño del problema.
# * Algoritmos de tiempo logarítmico: El tiempo de ejecución crece logarítmicamente con el tamaño del problema.
# * Algoritmos de tiempo polinomial: El tiempo de ejecución crece polinomialmente con el tamaño del problema.
# * Algoritmos de tiempo exponencial: El tiempo de ejecución crece exponencialmente con el tamaño del problema.
#
# **Estructura:**
# * Algoritmos lineales: Siguen una estructura secuencial simple.
# * Algoritmos ramificados: Presentan bifurcaciones o decisiones condicionales.
# * Algoritmos recursivos: Se invocan a sí mismos para resolver subproblemas más pequeños.
#
# # 👨‍💻 Diagrama de Flujo:
# Un diagrama de flujo representa la esquematización gráfica de un algoritmo, mostrando gráficamente los pasos o procesos a seguir para alcanzar la solución de un problema.

# %% [markdown]
# ### 🖥️Ilustración de un Algoritmo
# ![nskdsdzsd.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-06-26 a las 23.48.14_cb32e95a.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-06-26 a las 23.46.57_3e12a3fa.jpg](data:image/jpeg;base64,...)

# %%
# Definimos la función para calcular el área de un cuadrado
def calcular_area_cuadrado(lado):
  """
  Calcula el área de un cuadrado a partir de la longitud de su lado.

  Args:
    lado: Longitud del lado del cuadrado (valor numérico positivo).

  Returns:
    Área del cuadrado (valor numérico).
  """
  if lado <= 0:
    raise ValueError("El lado del cuadrado debe ser un valor numérico positivo.")
  else:
    area = lado * lado
    return area

# Ejemplo de uso de la función
lado_cuadrado = float(input("Ingrese la longitud del lado del cuadrado: "))
area_calculada = calcular_area_cuadrado(lado_cuadrado)

print(f"El área del cuadrado con lado de {lado_cuadrado} unidades es: {area_calculada:.2f} unidades cuadradas.")
# Out:
# Ingrese la longitud del lado del cuadrado: 5
# El área del cuadrado con lado de 5.0 unidades es: 25.00 unidades cuadradas.

# %% [markdown]
# # 🔄 Entrada, Proceso y Salida (E/P/S)
#
# ###Entrada:
#
# La entrada en programación se refiere a los datos o información que se introducen en un programa para ser procesados. Estos datos pueden provenir de diversas fuentes, como:
#
# Usuario: A través de interfaces gráficas (GUI), formularios de texto o comandos en la línea de comandos.
#
# Archivos: Lectura de contenido de archivos de texto, imágenes, audio o video.
#
# Dispositivos de entrada: Sensores, teclados, cámaras web, micrófonos, entre otros.
#
# Redes: Recepción de datos de otros programas o sistemas a través de redes informáticas.
#
# La entrada es crucial para proporcionar al programa la materia prima necesaria para realizar su función principal. La forma en que se captura, valida y procesa la entrada determina en gran medida la calidad del resultado final.
#
# ###⚙️Proceso:
#
# El proceso en programación se refiere a la transformación o manipulación de los datos de entrada para obtener un resultado o salida. Esta etapa implica la aplicación de algoritmos, estructuras de control, funciones y operaciones sobre los datos.
#
# El proceso es el núcleo de un programa, donde se define la lógica y las acciones que se deben realizar sobre la entrada para alcanzar el objetivo del programa. La eficiencia, precisión y robustez del proceso son aspectos fundamentales para garantizar el correcto funcionamiento del software.
#
# ### 📤Salida:
#
# La salida en programación se refiere al resultado final del proceso, que puede ser información, datos, productos físicos o acciones. La salida se presenta en un formato que puede ser utilizado por humanos, máquinas u otros sistemas.
#
# Algunos ejemplos comunes de salida en programación incluyen:
#
# * Mostrar texto en la pantalla: Consola, interfaces gráficas o ventanas emergentes.
# * Escribir datos en archivos: Guardar información en archivos de texto, imágenes, audio o video.
# * Controlar dispositivos: Encender o apagar luces, mover motores, reproducir sonidos, entre otros.
# * Enviar datos a redes: Transmitir información a otros programas o sistemas a través de redes informáticas.
# * La salida es la forma en que el programa comunica su resultado al usuario o al sistema que lo ejecuta.
# * La claridad, utilidad y formato adecuado de la salida son esenciales para una buena experiencia de usuario y una correcta interacción con el entorno.
#
# ![Texto alternativo](https://i0.wp.com/seainformatica2.mex.tl/imagesnew2/0/0/0/2/0/9/5/0/8/7/EPPSSS.jpg)
#
# ## 🔍 Búsqueda Lineal:
#
# La búsqueda lineal es un algoritmo simple e intuitivo que recorre un conjunto de datos elemento por elemento hasta encontrar el elemento buscado o determinar que no está presente. Se caracteriza por su facilidad de implementación y comprensión.
#
# ####Eficiencia:
#
# La búsqueda binaria tiene una complejidad temporal promedio de O(log n), lo que significa que el tiempo promedio que tarda el algoritmo en encontrar un elemento es logarítmico con respecto al tamaño del conjunto de datos (n). En otras palabras, a medida que aumenta el tamaño del conjunto de datos, el tiempo de búsqueda aumenta mucho más lentamente que en la búsqueda lineal.
#
# #### Casos de uso:
#
# La búsqueda binaria es ideal para conjuntos de datos grandes y ordenados, donde la eficiencia en el tiempo de búsqueda es crucial.
#
# ![Texto alternativo](https://naythgalaz.wordpress.com/wp-content/uploads/2013/04/busquedalineal.png)
#
# ## 🔍 Búsqueda Binaria:
#
# La búsqueda binaria es un algoritmo de búsqueda más eficiente que la búsqueda lineal, diseñado para funcionar en conjuntos de datos ordenados. Aprovecha la información del ordenamiento para reducir el espacio de búsqueda en cada iteración.
#
# #### Eficiencia:
#
# La búsqueda binaria tiene una complejidad temporal promedio de O(log n), lo que significa que el tiempo promedio que tarda el algoritmo en encontrar un elemento es logarítmico con respecto al tamaño del conjunto de datos (n). En otras palabras, a medida que aumenta el tamaño del conjunto de datos, el tiempo de búsqueda aumenta mucho más lentamente que en la búsqueda lineal.
#
# #### Casos de uso:
#
# La búsqueda binaria es ideal para conjuntos de datos grandes y ordenados, donde la eficiencia en el tiempo de búsqueda es crucial.
#
# ![Texto alternativo](https://uniwebsidad.com/static/libros/imagenes/algoritmos-python/f0801.png)
